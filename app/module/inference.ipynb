# %%
# 
# !pip install -r ./requirements.txt
# !cd ../ && pip install -r ../requirements.txt
# Out:
# Collecting alembic==1.11.1 (from -r ../requirements.txt (line 1))
#   Using cached alembic-1.11.1-py3-none-any.whl.metadata (7.2 kB)
# Collecting appdirs==1.4.4 (from -r ../requirements.txt (line 2))
#   Using cached appdirs-1.4.4-py2.py3-none-any.whl.metadata (9.0 kB)
# Collecting atomicwrites==1.4.0 (from -r ../requirements.txt (line 3))
#   Using cached atomicwrites-1.4.0-py2.py3-none-any.whl.metadata (5.6 kB)
# Collecting cloudinary==1.44.0 (from -r ../requirements.txt (line 4))
#   Using cached cloudinary-1.44.0-py3-none-any.whl.metadata (8.0 kB)
# Collecting dnspython==2.7.0 (from -r ../requirements.txt (line 5))
#   Using cached dnspython-2.7.0-py3-none-any.whl.metadata (5.8 kB)
# Collecting ecdsa==0.19.1 (from -r ../requirements.txt (line 6))
#   Using cached ecdsa-0.19.1-py2.py3-none-any.whl.metadata (29 kB)
# Collecting email_validator==2.2.0 (from -r ../requirements.txt (line 7))
#   Using cached email_validator-2.2.0-py3-none-any.whl.metadata (25 kB)
# Collecting fastapi==0.100.0 (from -r ../requirements.txt (line 8))
#   Using cached fastapi-0.100.0-py3-none-any.whl.metadata (23 kB)
# Collecting jsonpointer==2.1 (from -r ../requirements.txt (line 9))
#   Using cached jsonpointer-2.1-py2.py3-none-any.whl.metadata (2.4 kB)
# Collecting lxml==5.2.1 (from -r ../requirements.txt (line 10))
#   Using cached lxml-5.2.1-cp39-cp39-win_amd64.whl.metadata (3.5 kB)
# Collecting matplotlib==3.9.2 (from -r ../requirements.txt (line 11))
#   Using cached matplotlib-3.9.2-cp39-cp39-win_amd64.whl.metadata (11 kB)
# Collecting mkl-service==2.4.0 (from -r ../requirements.txt (line 12))
#   Using cached mkl_service-2.4.0-35-cp39-cp39-win_amd64.whl.metadata (2.4 kB)
# Collecting passlib==1.7.4 (from -r ../requirements.txt (line 13))
#   Using cached passlib-1.7.4-py2.py3-none-any.whl.metadata (1.7 kB)
# Collecting protobuf==4.25.3 (from -r ../requirements.txt (line 14))
#   Using cached protobuf-4.25.3-cp39-cp39-win_amd64.whl.metadata (541 bytes)
# Collecting psycopg2-binary==2.9.6 (from -r ../requirements.txt (line 15))
#   Using cached psycopg2_binary-2.9.6-cp39-cp39-win_amd64.whl.metadata (4.6 kB)
# Collecting pyasn1-modules==0.2.8 (from -r ../requirements.txt (line 16))
#   Using cached pyasn1_modules-0.2.8-py2.py3-none-any.whl.metadata (1.9 kB)
# Collecting pydantic==2.0.3 (from -r ../requirements.txt (line 17))
#   Using cached pydantic-2.0.3-py3-none-any.whl.metadata (128 kB)
# Collecting pydantic-settings==2.0.1 (from -r ../requirements.txt (line 18))
#   Using cached pydantic_settings-2.0.1-py3-none-any.whl.metadata (2.8 kB)
# Collecting pydantic_core==2.3.0 (from -r ../requirements.txt (line 19))
#   Using cached pydantic_core-2.3.0-cp39-none-win_amd64.whl.metadata (5.2 kB)
# Collecting pyls-spyder==0.4.0 (from -r ../requirements.txt (line 20))
#   Using cached pyls_spyder-0.4.0-py3-none-any.whl.metadata (4.6 kB)
# Collecting PyQt5==5.15.10 (from -r ../requirements.txt (line 21))
#   Using cached PyQt5-5.15.10-cp37-abi3-win_amd64.whl.metadata (2.2 kB)
# Collecting PyQtWebEngine==5.15.6 (from -r ../requirements.txt (line 22))
#   Using cached PyQtWebEngine-5.15.6-cp37-abi3-win_amd64.whl.metadata (1.9 kB)
# Collecting python-dotenv==1.0.0 (from -r ../requirements.txt (line 23))
#   Using cached python_dotenv-1.0.0-py3-none-any.whl.metadata (21 kB)
# Collecting python-jose==3.3.0 (from -r ../requirements.txt (line 24))
#   Using cached python_jose-3.3.0-py2.py3-none-any.whl.metadata (5.4 kB)
# Collecting python-multipart==0.0.6 (from -r ../requirements.txt (line 25))
#   Using cached python_multipart-0.0.6-py3-none-any.whl.metadata (2.5 kB)
# Collecting rsa==4.9.1 (from -r ../requirements.txt (line 26))
#   Using cached rsa-4.9.1-py3-none-any.whl.metadata (5.6 kB)
# Collecting setuptools==75.1.0 (from -r ../requirements.txt (line 27))
#   Downloading setuptools-75.1.0-py3-none-any.whl.metadata (6.9 kB)
# Collecting SQLAlchemy==2.0.19 (from -r ../requirements.txt (line 28))
#   Downloading SQLAlchemy-2.0.19-cp39-cp39-win_amd64.whl.metadata (9.7 kB)
# Collecting starlette==0.27.0 (from -r ../requirements.txt (line 29))
#   Using cached starlette-0.27.0-py3-none-any.whl.metadata (5.8 kB)
# Collecting uvicorn==0.22.0 (from -r ../requirements.txt (line 30))
#   Using cached uvicorn-0.22.0-py3-none-any.whl.metadata (6.3 kB)
# Collecting wheel==0.44.0 (from -r ../requirements.txt (line 31))
#   Downloading wheel-0.44.0-py3-none-any.whl.metadata (2.3 kB)
# Collecting Mako (from alembic==1.11.1->-r ../requirements.txt (line 1))
#   Downloading mako-1.3.10-py3-none-any.whl.metadata (2.9 kB)
# Requirement already satisfied: typing-extensions>=4 in c:\users\deno\appdata\roaming\python\python39\site-packages (from alembic==1.11.1->-r ../requirements.txt (line 1)) (4.12.2)
# Requirement already satisfied: six in c:\users\deno\appdata\roaming\python\python39\site-packages (from cloudinary==1.44.0->-r ../requirements.txt (line 4)) (1.17.0)
# Requirement already satisfied: urllib3>=1.26.5 in d:\conda\envs\tf_env\lib\site-packages (from cloudinary==1.44.0->-r ../requirements.txt (line 4)) (2.4.0)
# Requirement already satisfied: certifi in d:\conda\envs\tf_env\lib\site-packages (from cloudinary==1.44.0->-r ../requirements.txt (line 4)) (2025.4.26)
# Requirement already satisfied: idna>=2.0.0 in d:\conda\envs\tf_env\lib\site-packages (from email_validator==2.2.0->-r ../requirements.txt (line 7)) (3.10)
# Requirement already satisfied: contourpy>=1.0.1 in d:\conda\envs\tf_env\lib\site-packages (from matplotlib==3.9.2->-r ../requirements.txt (line 11)) (1.3.0)
# Requirement already satisfied: cycler>=0.10 in d:\conda\envs\tf_env\lib\site-packages (from matplotlib==3.9.2->-r ../requirements.txt (line 11)) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in d:\conda\envs\tf_env\lib\site-packages (from matplotlib==3.9.2->-r ../requirements.txt (line 11)) (4.57.0)
# Requirement already satisfied: kiwisolver>=1.3.1 in d:\conda\envs\tf_env\lib\site-packages (from matplotlib==3.9.2->-r ../requirements.txt (line 11)) (1.4.7)
# Requirement already satisfied: numpy>=1.23 in d:\conda\envs\tf_env\lib\site-packages (from matplotlib==3.9.2->-r ../requirements.txt (line 11)) (2.0.2)
# Requirement already satisfied: packaging>=20.0 in c:\users\deno\appdata\roaming\python\python39\site-packages (from matplotlib==3.9.2->-r ../requirements.txt (line 11)) (24.2)
# Requirement already satisfied: pillow>=8 in d:\conda\envs\tf_env\lib\site-packages (from matplotlib==3.9.2->-r ../requirements.txt (line 11)) (11.2.1)
# Requirement already satisfied: pyparsing>=2.3.1 in d:\conda\envs\tf_env\lib\site-packages (from matplotlib==3.9.2->-r ../requirements.txt (line 11)) (3.2.3)
# Requirement already satisfied: python-dateutil>=2.7 in c:\users\deno\appdata\roaming\python\python39\site-packages (from matplotlib==3.9.2->-r ../requirements.txt (line 11)) (2.9.0.post0)
# Requirement already satisfied: importlib-resources>=3.2.0 in d:\conda\envs\tf_env\lib\site-packages (from matplotlib==3.9.2->-r ../requirements.txt (line 11)) (6.5.2)
# Collecting mkl (from mkl-service==2.4.0->-r ../requirements.txt (line 12))
#   Downloading mkl-2025.1.0-py2.py3-none-win_amd64.whl.metadata (1.4 kB)
# Collecting pyasn1<0.5.0,>=0.4.6 (from pyasn1-modules==0.2.8->-r ../requirements.txt (line 16))
#   Downloading pyasn1-0.4.8-py2.py3-none-any.whl.metadata (1.5 kB)
# Collecting annotated-types>=0.4.0 (from pydantic==2.0.3->-r ../requirements.txt (line 17))
#   Using cached annotated_types-0.7.0-py3-none-any.whl.metadata (15 kB)
# Collecting python-lsp-server>=1.0.1 (from pyls-spyder==0.4.0->-r ../requirements.txt (line 20))
#   Downloading python_lsp_server-1.12.2-py3-none-any.whl.metadata (10 kB)
# Collecting PyQt5-sip<13,>=12.13 (from PyQt5==5.15.10->-r ../requirements.txt (line 21))
#   Downloading PyQt5_sip-12.17.0-cp39-cp39-win_amd64.whl.metadata (492 bytes)
# Collecting PyQt5-Qt5>=5.15.2 (from PyQt5==5.15.10->-r ../requirements.txt (line 21))
#   Downloading PyQt5_Qt5-5.15.2-py3-none-win_amd64.whl.metadata (552 bytes)
# Collecting PyQtWebEngine-Qt5>=5.15.0 (from PyQtWebEngine==5.15.6->-r ../requirements.txt (line 22))
#   Downloading PyQtWebEngine_Qt5-5.15.2-py3-none-win_amd64.whl.metadata (584 bytes)
# Collecting greenlet!=0.4.17 (from SQLAlchemy==2.0.19->-r ../requirements.txt (line 28))
#   Using cached greenlet-3.2.1-cp39-cp39-win_amd64.whl.metadata (4.2 kB)
# Collecting anyio<5,>=3.4.0 (from starlette==0.27.0->-r ../requirements.txt (line 29))
#   Using cached anyio-4.9.0-py3-none-any.whl.metadata (4.7 kB)
# Collecting click>=7.0 (from uvicorn==0.22.0->-r ../requirements.txt (line 30))
#   Using cached click-8.1.8-py3-none-any.whl.metadata (2.3 kB)
# Collecting h11>=0.8 (from uvicorn==0.22.0->-r ../requirements.txt (line 30))
#   Downloading h11-0.16.0-py3-none-any.whl.metadata (8.3 kB)
# Requirement already satisfied: exceptiongroup>=1.0.2 in c:\users\deno\appdata\roaming\python\python39\site-packages (from anyio<5,>=3.4.0->starlette==0.27.0->-r ../requirements.txt (line 29)) (1.2.2)
# Collecting sniffio>=1.1 (from anyio<5,>=3.4.0->starlette==0.27.0->-r ../requirements.txt (line 29))
#   Using cached sniffio-1.3.1-py3-none-any.whl.metadata (3.9 kB)
# Requirement already satisfied: colorama in d:\conda\envs\tf_env\lib\site-packages (from click>=7.0->uvicorn==0.22.0->-r ../requirements.txt (line 30)) (0.4.6)
# Requirement already satisfied: zipp>=3.1.0 in d:\conda\envs\tf_env\lib\site-packages (from importlib-resources>=3.2.0->matplotlib==3.9.2->-r ../requirements.txt (line 11)) (3.21.0)
# Collecting docstring-to-markdown (from python-lsp-server>=1.0.1->pyls-spyder==0.4.0->-r ../requirements.txt (line 20))
#   Downloading docstring_to_markdown-0.16-py3-none-any.whl.metadata (2.3 kB)
# Requirement already satisfied: importlib_metadata>=4.8.3 in d:\conda\envs\tf_env\lib\site-packages (from python-lsp-server>=1.0.1->pyls-spyder==0.4.0->-r ../requirements.txt (line 20)) (8.6.1)
# Requirement already satisfied: jedi<0.20.0,>=0.17.2 in c:\users\deno\appdata\roaming\python\python39\site-packages (from python-lsp-server>=1.0.1->pyls-spyder==0.4.0->-r ../requirements.txt (line 20)) (0.19.2)
# Collecting pluggy>=1.0.0 (from python-lsp-server>=1.0.1->pyls-spyder==0.4.0->-r ../requirements.txt (line 20))
#   Using cached pluggy-1.5.0-py3-none-any.whl.metadata (4.8 kB)
# Collecting python-lsp-jsonrpc<2.0.0,>=1.1.0 (from python-lsp-server>=1.0.1->pyls-spyder==0.4.0->-r ../requirements.txt (line 20))
#   Downloading python_lsp_jsonrpc-1.1.2-py3-none-any.whl.metadata (1.5 kB)
# Collecting ujson>=3.0.0 (from python-lsp-server>=1.0.1->pyls-spyder==0.4.0->-r ../requirements.txt (line 20))
#   Downloading ujson-5.10.0-cp39-cp39-win_amd64.whl.metadata (9.5 kB)
# Requirement already satisfied: MarkupSafe>=0.9.2 in d:\conda\envs\tf_env\lib\site-packages (from Mako->alembic==1.11.1->-r ../requirements.txt (line 1)) (3.0.2)
# Collecting intel-openmp<2026,>=2024 (from mkl->mkl-service==2.4.0->-r ../requirements.txt (line 12))
#   Downloading intel_openmp-2025.1.0-py2.py3-none-win_amd64.whl.metadata (1.3 kB)
# Collecting tbb==2022.* (from mkl->mkl-service==2.4.0->-r ../requirements.txt (line 12))
#   Downloading tbb-2022.1.0-py3-none-win_amd64.whl.metadata (1.1 kB)
# Collecting tcmlib==1.* (from tbb==2022.*->mkl->mkl-service==2.4.0->-r ../requirements.txt (line 12))
#   Downloading tcmlib-1.3.0-py2.py3-none-win_amd64.whl.metadata (1.0 kB)
# Collecting intel-cmplr-lib-ur==2025.1.0 (from intel-openmp<2026,>=2024->mkl->mkl-service==2.4.0->-r ../requirements.txt (line 12))
#   Downloading intel_cmplr_lib_ur-2025.1.0-py2.py3-none-win_amd64.whl.metadata (1.3 kB)
# Collecting umf==0.10.* (from intel-cmplr-lib-ur==2025.1.0->intel-openmp<2026,>=2024->mkl->mkl-service==2.4.0->-r ../requirements.txt (line 12))
#   Downloading umf-0.10.0-py2.py3-none-win_amd64.whl.metadata (1.1 kB)
# Requirement already satisfied: parso<0.9.0,>=0.8.4 in c:\users\deno\appdata\roaming\python\python39\site-packages (from jedi<0.20.0,>=0.17.2->python-lsp-server>=1.0.1->pyls-spyder==0.4.0->-r ../requirements.txt (line 20)) (0.8.4)
# Using cached alembic-1.11.1-py3-none-any.whl (224 kB)
# Downloading appdirs-1.4.4-py2.py3-none-any.whl (9.6 kB)
# Downloading atomicwrites-1.4.0-py2.py3-none-any.whl (6.8 kB)
# Using cached cloudinary-1.44.0-py3-none-any.whl (147 kB)
# Using cached dnspython-2.7.0-py3-none-any.whl (313 kB)
# Using cached ecdsa-0.19.1-py2.py3-none-any.whl (150 kB)
# Using cached email_validator-2.2.0-py3-none-any.whl (33 kB)
# Using cached fastapi-0.100.0-py3-none-any.whl (65 kB)
# Downloading jsonpointer-2.1-py2.py3-none-any.whl (7.4 kB)
# Downloading lxml-5.2.1-cp39-cp39-win_amd64.whl (3.8 MB)
#    ---------------------------------------- 0.0/3.8 MB ? eta -:--:--
#    -------- ------------------------------- 0.8/3.8 MB 6.7 MB/s eta 0:00:01
#    ------------------------ --------------- 2.4/3.8 MB 7.4 MB/s eta 0:00:01
#    -------------------------------------- - 3.7/3.8 MB 7.0 MB/s eta 0:00:01
#    ---------------------------------------- 3.8/3.8 MB 6.7 MB/s eta 0:00:00
# Downloading matplotlib-3.9.2-cp39-cp39-win_amd64.whl (7.8 MB)
#    ---------------------------------------- 0.0/7.8 MB ? eta -:--:--
#    ---------- ----------------------------- 2.1/7.8 MB 10.7 MB/s eta 0:00:01
#    ----------------- ---------------------- 3.4/7.8 MB 8.7 MB/s eta 0:00:01
#    -------------------------- ------------- 5.2/7.8 MB 8.8 MB/s eta 0:00:01
#    -------------------------------------- - 7.6/7.8 MB 9.2 MB/s eta 0:00:01
#    ---------------------------------------- 7.8/7.8 MB 9.1 MB/s eta 0:00:00
# Downloading mkl_service-2.4.0-35-cp39-cp39-win_amd64.whl (44 kB)
# Using cached passlib-1.7.4-py2.py3-none-any.whl (525 kB)
# Downloading protobuf-4.25.3-cp39-cp39-win_amd64.whl (413 kB)
# Downloading psycopg2_binary-2.9.6-cp39-cp39-win_amd64.whl (1.2 MB)
#    ---------------------------------------- 0.0/1.2 MB ? eta -:--:--
#    ---------------------------------------- 1.2/1.2 MB 9.7 MB/s eta 0:00:00
# Downloading pyasn1_modules-0.2.8-py2.py3-none-any.whl (155 kB)
# Using cached pydantic-2.0.3-py3-none-any.whl (364 kB)
# Using cached pydantic_settings-2.0.1-py3-none-any.whl (11 kB)
# Downloading pydantic_core-2.3.0-cp39-none-win_amd64.whl (1.7 MB)
#    ---------------------------------------- 0.0/1.7 MB ? eta -:--:--
#    ------------------------------------- -- 1.6/1.7 MB 7.6 MB/s eta 0:00:01
#    ---------------------------------------- 1.7/1.7 MB 7.7 MB/s eta 0:00:00
# Downloading pyls_spyder-0.4.0-py3-none-any.whl (8.1 kB)
# Downloading PyQt5-5.15.10-cp37-abi3-win_amd64.whl (6.8 MB)
#    ---------------------------------------- 0.0/6.8 MB ? eta -:--:--
#    ---------------- ----------------------- 2.9/6.8 MB 15.2 MB/s eta 0:00:01
#    ------------------------------ --------- 5.2/6.8 MB 12.7 MB/s eta 0:00:01
#    ------------------------------------ --- 6.3/6.8 MB 10.2 MB/s eta 0:00:01
#    ---------------------------------------- 6.8/6.8 MB 10.0 MB/s eta 0:00:00
# Downloading PyQtWebEngine-5.15.6-cp37-abi3-win_amd64.whl (182 kB)
# Using cached python_dotenv-1.0.0-py3-none-any.whl (19 kB)
# Using cached python_jose-3.3.0-py2.py3-none-any.whl (33 kB)
# Using cached python_multipart-0.0.6-py3-none-any.whl (45 kB)
# Using cached rsa-4.9.1-py3-none-any.whl (34 kB)
# Downloading setuptools-75.1.0-py3-none-any.whl (1.2 MB)
#    ---------------------------------------- 0.0/1.2 MB ? eta -:--:--
#    ---------------------------------------- 1.2/1.2 MB 12.6 MB/s eta 0:00:00
# Downloading SQLAlchemy-2.0.19-cp39-cp39-win_amd64.whl (2.0 MB)
#    ---------------------------------------- 0.0/2.0 MB ? eta -:--:--
#    ---------------------------------------- 2.0/2.0 MB 10.1 MB/s eta 0:00:00
# Using cached starlette-0.27.0-py3-none-any.whl (66 kB)
# Using cached uvicorn-0.22.0-py3-none-any.whl (58 kB)
# Downloading wheel-0.44.0-py3-none-any.whl (67 kB)
# Using cached annotated_types-0.7.0-py3-none-any.whl (13 kB)
# Using cached anyio-4.9.0-py3-none-any.whl (100 kB)
# Using cached click-8.1.8-py3-none-any.whl (98 kB)
# Using cached greenlet-3.2.1-cp39-cp39-win_amd64.whl (294 kB)
# Downloading h11-0.16.0-py3-none-any.whl (37 kB)
# Downloading pyasn1-0.4.8-py2.py3-none-any.whl (77 kB)
# Downloading PyQt5_Qt5-5.15.2-py3-none-win_amd64.whl (50.1 MB)
#    ---------------------------------------- 0.0/50.1 MB ? eta -:--:--
#    - -------------------------------------- 1.6/50.1 MB 8.4 MB/s eta 0:00:06
#    -- ------------------------------------- 3.1/50.1 MB 8.4 MB/s eta 0:00:06
#    ---- ----------------------------------- 5.2/50.1 MB 8.4 MB/s eta 0:00:06
#    ----- ---------------------------------- 7.1/50.1 MB 8.6 MB/s eta 0:00:06
#    ------- -------------------------------- 9.4/50.1 MB 8.9 MB/s eta 0:00:05
#    --------- ------------------------------ 11.8/50.1 MB 9.3 MB/s eta 0:00:05
#    ----------- ---------------------------- 14.4/50.1 MB 9.7 MB/s eta 0:00:04
#    -------------- ------------------------- 17.6/50.1 MB 10.5 MB/s eta 0:00:04
#    ---------------- ----------------------- 20.7/50.1 MB 11.0 MB/s eta 0:00:03
#    ------------------- -------------------- 24.9/50.1 MB 12.0 MB/s eta 0:00:03
#    --------------------- ------------------ 27.5/50.1 MB 11.9 MB/s eta 0:00:02
#    ------------------------ --------------- 30.9/50.1 MB 12.2 MB/s eta 0:00:02
#    -------------------------- ------------- 33.3/50.1 MB 12.1 MB/s eta 0:00:02
#    ----------------------------- ----------
9 MB/s eta 0:00:02
#    ----------------------------------- ---- 134.0/151.1 MB 9.9 MB/s eta 0:00:02
#    ----------------------------------- ---- 135.8/151.1 MB 9.9 MB/s eta 0:00:02
#    ------------------------------------ --- 137.6/151.1 MB 9.8 MB/s eta 0:00:02
#    ------------------------------------ --- 139.7/151.1 MB 9.9 MB/s eta 0:00:02
#    ------------------------------------- -- 141.6/151.1 MB 9.8 MB/s eta 0:00:01
#    -------------------------------------- - 143.7/151.1 MB 9.8 MB/s eta 0:00:01
#    -------------------------------------- - 145.0/151.1 MB 9.8 MB/s eta 0:00:01
#    -------------------------------------- - 146.8/151.1 MB 9.8 MB/s eta 0:00:01
#    ---------------------------------------  148.1/151.1 MB 9.7 MB/s eta 0:00:01
#    ---------------------------------------  149.4/151.1 MB 9.7 MB/s eta 0:00:01
#    ---------------------------------------  151.0/151.1 MB 9.7 MB/s eta 0:00:01
#    ---------------------------------------- 151.1/151.1 MB 9.5 MB/s eta 0:00:00
# Downloading tbb-2022.1.0-py3-none-win_amd64.whl (299 kB)
# Downloading tcmlib-1.3.0-py2.py3-none-win_amd64.whl (356 kB)
# Downloading intel_openmp-2025.1.0-py2.py3-none-win_amd64.whl (12.7 MB)
#    ---------------------------------------- 0.0/12.7 MB ? eta -:--:--
#    ---- ----------------------------------- 1.3/12.7 MB 7.5 MB/s eta 0:00:02
#    ---------- ----------------------------- 3.4/12.7 MB 8.8 MB/s eta 0:00:02
#    --------------- ------------------------ 5.0/12.7 MB 8.4 MB/s eta 0:00:01
#    ------------------- -------------------- 6.3/12.7 MB 7.9 MB/s eta 0:00:01
#    ----------------------- ---------------- 7.3/12.7 MB 7.2 MB/s eta 0:00:01
#    ---------------------------- ----------- 9.2/12.7 MB 7.5 MB/s eta 0:00:01
#    --------------------------------- ------ 10.7/12.7 MB 7.5 MB/s eta 0:00:01
#    -------------------------------------- - 12.3/12.7 MB 7.4 MB/s eta 0:00:01
#    ---------------------------------------- 12.7/12.7 MB 7.4 MB/s eta 0:00:00
# Downloading intel_cmplr_lib_ur-2025.1.0-py2.py3-none-win_amd64.whl (1.1 MB)
#    ---------------------------------------- 0.0/1.1 MB ? eta -:--:--
#    ---------------------------------------- 1.1/1.1 MB 12.9 MB/s eta 0:00:00
# Downloading umf-0.10.0-py2.py3-none-win_amd64.whl (193 kB)
# Using cached pluggy-1.5.0-py3-none-any.whl (20 kB)
# Downloading python_lsp_jsonrpc-1.1.2-py3-none-any.whl (8.8 kB)
# Using cached sniffio-1.3.1-py3-none-any.whl (10 kB)
# Downloading ujson-5.10.0-cp39-cp39-win_amd64.whl (42 kB)
# Downloading docstring_to_markdown-0.16-py3-none-any.whl (23 kB)
# Installing collected packages: tcmlib, PyQtWebEngine-Qt5, PyQt5-Qt5, pyasn1, passlib, appdirs, wheel, umf, ujson, tbb, sniffio, setuptools, rsa, python-multipart, python-dotenv, PyQt5-sip, pydantic_core, pyasn1-modules, psycopg2-binary, protobuf, pluggy, Mako, lxml, jsonpointer, h11, greenlet, ecdsa, dnspython, cloudinary, click, atomicwrites, annotated-types, uvicorn, SQLAlchemy, python-lsp-jsonrpc, python-jose, PyQt5, pydantic, matplotlib, intel-cmplr-lib-ur, email_validator, docstring-to-markdown, anyio, starlette, python-lsp-server, PyQtWebEngine, pydantic-settings, intel-openmp, alembic, pyls-spyder, mkl, fastapi, mkl-service
#   Attempting uninstall: wheel
#     Found existing installation: wheel 0.45.1
#     Uninstalling wheel-0.45.1:
#       Successfully uninstalled wheel-0.45.1
#   Attempting uninstall: setuptools
#     Found existing installation: setuptools 79.0.1
#     Uninstalling setuptools-79.0.1:
#       Successfully uninstalled setuptools-79.0.1
#   Attempting uninstall: protobuf
#     Found existing installation: protobuf 5.29.4
#     Uninstalling protobuf-5.29.4:
#       Successfully uninstalled protobuf-5.29.4
#   Attempting uninstall: matplotlib
#     Found existing installation: matplotlib 3.9.4
#     Uninstalling matplotlib-3.9.4:
#       Successfully uninstalled matplotlib-3.9.4
# Successfully installed Mako-1.3.10 PyQt5-5.15.10 PyQt5-Qt5-5.15.2 PyQt5-sip-12.17.0 PyQtWebEngine-5.15.6 PyQtWebEngine-Qt5-5.15.2 SQLAlchemy-2.0.19 alembic-1.11.1 annotated-types-0.7.0 anyio-4.9.0 appdirs-1.4.4 atomicwrites-1.4.0 click-8.1.8 cloudinary-1.44.0 dnspython-2.7.0 docstring-to-markdown-0.16 ecdsa-0.19.1 email_validator-2.2.0 fastapi-0.100.0 greenlet-3.2.1 h11-0.16.0 intel-cmplr-lib-ur-2025.1.0 intel-openmp-2025.1.0 jsonpointer-2.1 lxml-5.2.1 matplotlib-3.9.2 mkl-2025.1.0 mkl-service-2.4.0 passlib-1.7.4 pluggy-1.5.0 protobuf-4.25.3 psycopg2-binary-2.9.6 pyasn1-0.4.8 pyasn1-modules-0.2.8 pydantic-2.0.3 pydantic-settings-2.0.1 pydantic_core-2.3.0 pyls-spyder-0.4.0 python-dotenv-1.0.0 python-jose-3.3.0 python-lsp-jsonrpc-1.1.2 python-lsp-server-1.12.2 python-multipart-0.0.6 rsa-4.9.1 setuptools-75.1.0 sniffio-1.3.1 starlette-0.27.0 tbb-2022.1.0 tcmlib-1.3.0 ujson-5.10.0 umf-0.10.0 uvicorn-0.22.0 wheel-0.44.0
#   WARNING: Failed to remove contents in a temporary directory 'D:\Conda\envs\tf_env\Lib\site-packages\google\~upb'.
#   You can safely remove it manually.
#   WARNING: Failed to remove contents in a temporary directory 'D:\Conda\envs\tf_env\Lib\site-packages\~atplotlib'.
#   You can safely remove it manually.

# %%
# !pip freeze > requirements.txt

# %%
# pip install tflite-runtime

# %%
import tensorflow as tf

from skimage import io
from imutils.object_detection import non_max_suppression

import numpy as np
import math
import time
import cv2
import string

# %%
def getDetBoxes_core(textmap, linkmap, text_threshold, link_threshold, low_text):
    # prepare data
    linkmap = linkmap.copy()
    textmap = textmap.copy()
    img_h, img_w = textmap.shape

    """ labeling method """
    ret, text_score = cv2.threshold(textmap, low_text, 1, 0)
    ret, link_score = cv2.threshold(linkmap, link_threshold, 1, 0)

    text_score_comb = np.clip(text_score + link_score, 0, 1)
    nLabels, labels, stats, centroids = cv2.connectedComponentsWithStats(text_score_comb.astype(np.uint8), connectivity=4)

    det = []
    mapper = []
    for k in range(1,nLabels):
        # size filtering
        size = stats[k, cv2.CC_STAT_AREA]
        if size < 10: continue

        # thresholding
        if np.max(textmap[labels==k]) < text_threshold: continue

        # make segmentation map
        segmap = np.zeros(textmap.shape, dtype=np.uint8)
        segmap[labels==k] = 255
        segmap[np.logical_and(link_score==1, text_score==0)] = 0   # remove link area
        x, y = stats[k, cv2.CC_STAT_LEFT], stats[k, cv2.CC_STAT_TOP]
        w, h = stats[k, cv2.CC_STAT_WIDTH], stats[k, cv2.CC_STAT_HEIGHT]
        niter = int(math.sqrt(size * min(w, h) / (w * h)) * 2)
        sx, ex, sy, ey = x - niter, x + w + niter + 1, y - niter, y + h + niter + 1
        # boundary check
        if sx < 0 : sx = 0
        if sy < 0 : sy = 0
        if ex >= img_w: ex = img_w
        if ey >= img_h: ey = img_h
        kernel = cv2.getStructuringElement(cv2.MORPH_RECT,(1 + niter, 1 + niter))
        segmap[sy:ey, sx:ex] = cv2.dilate(segmap[sy:ey, sx:ex], kernel)

        # make box
        np_contours = np.roll(np.array(np.where(segmap!=0)),1,axis=0).transpose().reshape(-1,2)
        rectangle = cv2.minAreaRect(np_contours)
        box = cv2.boxPoints(rectangle)

        # align diamond-shape
        w, h = np.linalg.norm(box[0] - box[1]), np.linalg.norm(box[1] - box[2])
        box_ratio = max(w, h) / (min(w, h) + 1e-5)
        if abs(1 - box_ratio) <= 0.1:
            l, r = min(np_contours[:,0]), max(np_contours[:,0])
            t, b = min(np_contours[:,1]), max(np_contours[:,1])
            box = np.array([[l, t], [r, t], [r, b], [l, b]], dtype=np.float32)

        # make clock-wise order
        startidx = box.sum(axis=1).argmin()
        box = np.roll(box, 4-startidx, 0)
        box = np.array(box)

        det.append(box)
        mapper.append(k)

    return det, labels, mapper

def adjustResultCoordinates(polys, ratio_w, ratio_h, ratio_net = 2):
    if len(polys) > 0:
        polys = np.array(polys)
        for k in range(len(polys)):
            if polys[k] is not None:
                polys[k] *= (ratio_w * ratio_net, ratio_h * ratio_net)
    return polys
  
# Postprocessing output from craft TFLite Model
def postprocess_craft(y, feature, image):
    score_text = y[0,:,:,0]
    score_link = y[0,:,:,1]
    text_threshold = 0.7
    link_threshold = 0.4
    low_text = 0.4
    ratio_w = ratio_h = 1
    boxes, labels, mapper = getDetBoxes_core(score_text, score_link, text_threshold, link_threshold, low_text)
    polys = [None] * len(boxes)
    boxes = adjustResultCoordinates(boxes, ratio_w, ratio_h)
    for k in range(len(polys)):
        if polys[k] is None: polys[k] = boxes[k]
    output_image = image[:,:,::-1].copy()
    crops = list()
    for i, box in enumerate(polys):
        poly = np.array(box).astype(np.int32).reshape((-1))
        poly = poly.reshape(-1, 2)
        min_co = tuple(np.min(poly, axis=0))
        max_co = tuple(np.max(poly, axis=0))
        cv2.rectangle(output_image, min_co, max_co, (0, 0, 255), 2)
        crops.append([min_co, max_co])
    return output_image, crops

# %%
def preprocess_ocr(image):
    input_data = cv2.cvtColor(image, cv2.COLOR_BGR2GRAY)
    input_data = cv2.resize(input_data, (200, 31))
    input_data = input_data[np.newaxis]
    input_data = np.expand_dims(input_data, 3)
    input_data = input_data.astype('float32')/255
    return input_data

def run_tflite_ocr(input_data):
    interpreter = tf.lite.Interpreter(model_path='./keras_ocr_float16_ctc.tflite')
    interpreter.allocate_tensors()

    # Get input and output tensors.
    input_details = interpreter.get_input_details()
    output_details = interpreter.get_output_details()

    input_shape = input_details[0]['shape']
    interpreter.set_tensor(input_details[0]['index'], input_data)

    interpreter.invoke()

    output = interpreter.get_tensor(output_details[0]['index'])
    return output

alphabets = string.digits + string.ascii_lowercase
blank_index = len(alphabets)
  
def postprocess_ocr(output, greedy=True):
  # Running decoder on TFLite Output
    final_output = "".join(alphabets[index] for index in output[0] if index not in [blank_index, -1])
    return final_output

# %%
def tflite_inference(input):
    model_name = "./crnn_float16.tflite"
    interpreter = tf.lite.Interpreter(model_path=model_name)
    input_details = interpreter.get_input_details()
    output_details = interpreter.get_output_details()
    interpreter.allocate_tensors()
    interpreter.set_tensor(input_details[0]['index'], input)
    interpreter.invoke()
    output = interpreter.get_tensor(output_details[0]['index'])
    return output

def ctc_decode(preds):
    pred_index = np.argmax(preds, axis=2)
    # char_list = list(opt.character)
    char_list = list("0123456789abcdefghijklmnopqrstuvwxyz")
    char_dict = {}
    for i, char in enumerate(char_list):
        char_dict[char] = i + 1
    char_list = ['_'] + char_list
    BLANK = 0
    texts = []
    output = pred_index[0, :]
    characters = []
    for i in range(preds.shape[1]):
        if output[i] != BLANK and (not (i > 0 and output[i - 1] == output[i])):
            characters.append(char_list[output[i]])
        text = ''.join(characters)
    return text

# %%
image_path = "D:\OCR\ocr_tflite\images\image.png"

# %%
import concurrent.futures
import numpy as np
import cv2
import tensorflow as tf
from skimage import io

class TensorflowLiteOCR:
    def __init__(self):
        self.craft_float_model = tf.lite.Interpreter(model_path='./craft_float_800.tflite')
        self.craft_float_model.allocate_tensors()
        self.crnn_float_model = tf.lite.Interpreter(model_path='./crnn_dr.tflite')
        self.crnn_float_model.allocate_tensors()

    def crnn_inference(self, input, interpreter):
        interpreter.allocate_tensors()
        input_details = interpreter.get_input_details()
        output_details = interpreter.get_output_details()
        interpreter.set_tensor(input_details[0]['index'], input)
        interpreter.invoke()
        output = interpreter.get_tensor(output_details[0]['index'])
        return output

    def ctc_decode(self, preds):
        pred_index = np.argmax(preds, axis=2)
        char_list = list("0123456789abcdefghijklmnopqrstuvwxyz")
        char_dict = {char: i + 1 for i, char in enumerate(char_list)}
        char_list = ['_'] + char_list
        BLANK = 0
        texts = []
        output = pred_index[0, :]
        characters = []
        for i in range(preds.shape[1]):
            if output[i] != BLANK and (not (i > 0 and output[i - 1] == output[i])):
                characters.append(char_list[output[i]])
        text = ''.join(characters)
        return text

    def craft_preprocess(self, image_path):
        image = io.imread(image_path)
        if image.shape[2] == 4:
            image = cv2.cvtColor(image, cv2.COLOR_RGBA2RGB)
        if image.shape[2] == 1:
            image = cv2.cvtColor(image, cv2.COLOR_GRAY2RGB)

        image = np.array(image).astype(np.float32)
        input_image = cv2.resize(image, dsize=(600, 800), interpolation=cv2.INTER_LINEAR)
        store_input_image = input_image.copy()
        mean = (0.485, 0.456, 0.406)
        variance = (0.229, 0.224, 0.225)
        input_image -= np.array([mean[0] * 255.0, mean[1] * 255.0, mean[2] * 255.0], dtype=np.float32)
        input_image /= np.array([variance[0] * 255.0, variance[1] * 255.0, variance[2] * 255.0], dtype=np.float32)
        image = np.transpose(input_image, (2, 0, 1))
        preprocessed_image = image[np.newaxis]
        return store_input_image, preprocessed_image

    def craft_tflite_model(self, input_data):
        interpreter = self.craft_float_model
        input_details = interpreter.get_input_details()
        output_details = interpreter.get_output_details()
        interpreter.set_tensor(input_details[0]['index'], input_data)
        interpreter.invoke()
        y = interpreter.get_tensor(output_details[0]['index'])
        feature = interpreter.get_tensor(output_details[1]['index'])
        return y, feature

    def ocr_model(self, image, model):
        if model == 'crnn':
            image = cv2.cvtColor(image, cv2.COLOR_BGR2GRAY)
            image = image / 127.5 - 1.0
            image = cv2.resize(image, (100, 32), interpolation=cv2.INTER_CUBIC)
            image = np.expand_dims(image, 0)
            image = np.expand_dims(image, 0)
            image = np.float32(image)

            # Create a new interpreter for each thread
            interpreter = tf.lite.Interpreter(model_path='./crnn_dr.tflite')
            text = self.crnn_inference(image, interpreter)
            decoded_text = self.ctc_decode(text)
            return decoded_text
        return None

    def process_box(self, box, input_image, index):
        cropped_image = input_image[box[0][1]:box[1][1], box[0][0]:box[1][0], :]
        final_output = self.ocr_model(cropped_image, 'crnn')
        return (index, box, final_output)

    def run(self, image_path):
        input_image, preprocessed_image = self.craft_preprocess(image_path)
        y, feature = self.craft_tflite_model(preprocessed_image)

        # Assuming `postprocess_craft` function is defined elsewhere to process the model output
        output, crops = postprocess_craft(y, feature, input_image)

        final_text = ""
        boxes_with_labels = []

        # Using ThreadPoolExecutor for multi-threaded inference, while preserving order
        with concurrent.futures.ThreadPoolExecutor() as executor:
            futures = [executor.submit(self.process_box, box, input_image, index) for index, box in enumerate(crops)]
            results = []
            for future in concurrent.futures.as_completed(futures):
                result = future.result()
                results.append(result)

        # Sort results based on the original indices to maintain the order
        results.sort(key=lambda x: x[0])

        # Collect the final results in order
        for _, box, final_output in results:
            if final_output:
                final_text += final_output + " "
                boxes_with_labels.append({'box': box, 'label': final_output})

        return {'final_text': final_text.strip(), 'boxes': boxes_with_labels}

# %%
ocr = TensorflowLiteOCR()

# %%
data = ocr.run("D:\OCR\ocr_tflite\images\image.png")
# inline to show the image in jupyter notebook
# import matplotlib.pyplot as plt
# plt.imshow(image)

# plt.axis('off')

print("Final Text: ", data['final_text'])
# Out:
# Final Text:  problems 19 output debug console terminal ports setis96111765 13 o61354gt14s906 nat1986bbel1l 17 u cnobridgey decoded i log textt cnobridgey ocr results for image ftextt sample textt boxes d log o3 inobridge log token from scnnmnmenstainc stores eyjzo uwertnplingeonatians p20hl nggeconfiontnwegyes gocbaemert token from scnonmanmenstinc cnobridged log stores eyjzo cntennagionogeanahiang p20hy gocbaemert aggecolfiontnweys unable jassetsycraft detection tfliter from hooks resolve text dr lusel to undefined wlassetsycraft cnobridged error errors unable to resolve module ovetsyadroidaoroid app imobilelhooks lusetextletector tsx files of these existt none craft text detection dr tflite lcraft detection dr tflite assets text 103 load the craft detection model text 104 crafttextuetector uselensorflowacal const 105 requirel lassetsycraft detection tflite text dr 106 107 108 load the ocr modell unable jassetsycraft detection tfliter from hooks to resolve text dr lusel undefined unable resolve module wassetsycraft cnobridgey error lerrort to umobilelhooks ovectsyandroidacoroid app lusetextiletector tsx toe
